# %%
from __future__ import print_function
import numpy as np
from tensorflow import keras
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import os
from datetime import datetime
import io
import itertools
from packaging import version
from six.moves import range
import tensorflow as tf
import matplotlib.pyplot as plt
import sklearn.metrics

batch_size = 256
num_classes = 50
epochs = 100
data_augmentation = True
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar50_trained_model.h5'

class_names = np.array([
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
])

class_names = class_names[1::2]

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
train_filter = y_train % 2 != 0
test_filter = y_test % 2 != 0
train_filter = train_filter.flatten()
test_filter = test_filter.flatten()
x_train = x_train[train_filter]
y_train = y_train[train_filter]
x_test = x_test[test_filter]
y_test = y_test[test_filter]
y_train = np.array(list(map(lambda x: (x - 1) / 2, y_train)))
y_test = np.array(list(map(lambda x: (x - 1) / 2, y_test)))

logdir = "logs/plots/" + datetime.now().strftime("%Y%m%d-%H%M%S")
file_writer = tf.summary.create_file_writer(logdir)
file_writer_cm = tf.summary.create_file_writer(logdir + '/cm')

def log_confusion_matrix(epoch, logs):
  # Use the model to predict the values from the validation dataset.
  test_pred_raw = model.predict(x_test)
  test_pred = np.argmax(test_pred_raw, axis=1)

  # Calculate the confusion matrix.
  cm = sklearn.metrics.confusion_matrix(y_test, test_pred)
  # Log the confusion matrix as an image summary.
  figure = plot_confusion_matrix(cm, class_names=class_names)
  cm_image = plot_to_image(figure)

  # Log the confusion matrix as an image summary.
  with file_writer_cm.as_default():
    tf.summary.image("Confusion Matrix", cm_image, step=epoch)

# Define the per-epoch callback.
cm_callback = keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)

def plot_confusion_matrix(cm, class_names):
  """
  Returns a matplotlib figure containing the plotted confusion matrix.

  Args:
    cm (array, shape = [n, n]): a confusion matrix of integer classes
    class_names (array, shape = [n]): String names of the integer classes
  """
  figure = plt.figure(figsize=(40, 40))
  plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
  plt.title("Confusion matrix")
  plt.colorbar()
  tick_marks = np.arange(len(class_names))
  plt.xticks(tick_marks, class_names, rotation=45)
  plt.yticks(tick_marks, class_names)

  # Normalize the confusion matrix.
  cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

  # Use white text if squares are dark; otherwise black.
  threshold = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    color = "white" if cm[i, j] > threshold else "black"
    plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  return figure

def plot_to_image(figure):
  """Converts the matplotlib plot specified by 'figure' to a PNG image and
  returns it. The supplied figure is closed and inaccessible after this call."""
  # Save the plot to a PNG in memory.
  buf = io.BytesIO()
  plt.savefig(buf, format='png')
  # Closing the figure prevents it from being displayed directly inside
  # the notebook.
  plt.close(figure)
  buf.seek(0)
  # Convert PNG buffer to TF image
  image = tf.image.decode_png(buf.getvalue(), channels=4)
  # Add the batch dimension
  image = tf.expand_dims(image, 0)
  return image

def image_grid():
  """Return a 5x5 grid of the MNIST images as a matplotlib figure."""
  # Create a figure to contain the plot.
  figure = plt.figure(figsize=(10,10))
  for i in range(25):
    # Start next subplot.
    plt.subplot(5, 5, i + 1, title=class_names[int(y_train[i][0])])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
  
  return figure

# Prepare the plot
figure = image_grid()
# Convert to image and log
with file_writer.as_default():
  tf.summary.image("Training data", plot_to_image(figure), step=0)
# Convert class vectors to binary class matrices.
y_train_matrix = keras.utils.to_categorical(y_train, num_classes)
y_test_matrix = keras.utils.to_categorical(y_test, num_classes)

if os.path.exists(os.path.join(save_dir, model_name)):
  model = keras.models.load_model(os.path.join(save_dir, model_name))
  print("model loaded")
else:
  model = Sequential()

  model.add(Conv2D(128, (3, 3), padding='same', input_shape=x_train.shape[1:]))
  model.add(Activation('elu'))
  model.add(Conv2D(128, (3, 3)))
  model.add(Activation('elu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.1))

  model.add(Conv2D(256, (3, 3), padding='same'))
  model.add(Activation('elu'))
  model.add(Conv2D(256, (3, 3)))
  model.add(Activation('elu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))

  model.add(Conv2D(512, (3, 3), padding='same'))
  model.add(Activation('elu'))
  model.add(Conv2D(512, (3, 3)))
  model.add(Activation('elu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.5))

  model.add(Flatten())
  model.add(Dense(1024))
  model.add(Activation('elu'))
  model.add(Dropout(0.5))
  model.add(Dense(num_classes))
  model.add(Activation('softmax'))

  # initiate RMSprop optimizer
  opt = keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

  # Let's train the model using RMSprop
  model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
  print("new model created")

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

logdir = "logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)


# Sets up a timestamped log directory.
logdir = "logs/train_data/" + datetime.now().strftime("%Y%m%d-%H%M%S")
# Creates a file writer for the log directory.
file_writer = tf.summary.create_file_writer(logdir)

with file_writer.as_default():
  # Don't forget to reshape.
  images = np.reshape(x_train[0:25], (-1, 32, 32, 3))
  tf.summary.image("25 training data examples", images, max_outputs=25, step=0)



if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train_matrix,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test_matrix),
              shuffle=True,
              callbacks=[tensorboard_callback, cm_callback])
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit(datagen.flow(x_train, y_train_matrix,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test_matrix),
                        callbacks=[tensorboard_callback, cm_callback])

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test_matrix, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# !zip -r /content/file.zip /content
from google.colab import files
files.download("/content/file.zip")
# Out:
# model loaded
# Using real-time data augmentation.
# Epoch 1/100
# 98/98 [==============================] - 24s 246ms/step - loss: 0.1820 - accuracy: 0.9413 - val_loss: 1.2248 - val_accuracy: 0.7518
# Epoch 2/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1854 - accuracy: 0.9410 - val_loss: 1.1754 - val_accuracy: 0.7594
# Epoch 3/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1846 - accuracy: 0.9406 - val_loss: 1.1355 - val_accuracy: 0.7590
# Epoch 4/100
# 98/98 [==============================] - 22s 225ms/step - loss: 0.1857 - accuracy: 0.9393 - val_loss: 1.2001 - val_accuracy: 0.7550
# Epoch 5/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1939 - accuracy: 0.9383 - val_loss: 1.1516 - val_accuracy: 0.7538
# Epoch 6/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1887 - accuracy: 0.9375 - val_loss: 1.2848 - val_accuracy: 0.7492
# Epoch 7/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1895 - accuracy: 0.9413 - val_loss: 1.1825 - val_accuracy: 0.7538
# Epoch 8/100
# 98/98 [==============================] - 37s 379ms/step - loss: 0.1899 - accuracy: 0.9391 - val_loss: 1.1413 - val_accuracy: 0.7594
# Epoch 9/100
# 98/98 [==============================] - 22s 225ms/step - loss: 0.1859 - accuracy: 0.9403 - val_loss: 1.1904 - val_accuracy: 0.7542
# Epoch 10/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1893 - accuracy: 0.9406 - val_loss: 1.1350 - val_accuracy: 0.7484
# Epoch 11/100
# 98/98 [==============================] - 23s 234ms/step - loss: 0.1843 - accuracy: 0.9416 - val_loss: 1.3706 - val_accuracy: 0.7490
# Epoch 12/100
# 98/98 [==============================] - 22s 226ms/step - loss: 0.1901 - accuracy: 0.9396 - val_loss: 1.2321 - val_accuracy: 0.7556
# Epoch 13/100
# 98/98 [==============================] - 22s 226ms/step - loss: 0.1904 - accuracy: 0.9390 - val_loss: 1.2547 - val_accuracy: 0.7578
# Epoch 14/100
# 98/98 [==============================] - 23s 236ms/step - loss: 0.1855 - accuracy: 0.9411 - val_loss: 1.1779 - val_accuracy: 0.7472
# Epoch 15/100
# 98/98 [==============================] - 22s 227ms/step - loss: 0.1866 - accuracy: 0.9402 - val_loss: 1.1840 - val_accuracy: 0.7548
# Epoch 16/100
# 98/98 [==============================] - 22s 225ms/step - loss: 0.1843 - accuracy: 0.9401 - val_loss: 1.1963 - val_accuracy: 0.7566
# Epoch 17/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1826 - accuracy: 0.9416 - val_loss: 1.1416 - val_accuracy: 0.7544
# Epoch 18/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1850 - accuracy: 0.9409 - val_loss: 1.1903 - val_accuracy: 0.7530
# Epoch 19/100
# 98/98 [==============================] - 23s 237ms/step - loss: 0.1840 - accuracy: 0.9418 - val_loss: 1.2759 - val_accuracy: 0.7536
# Epoch 20/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1821 - accuracy: 0.9428 - val_loss: 1.2041 - val_accuracy: 0.7500
# Epoch 21/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1882 - accuracy: 0.9419 - val_loss: 1.2560 - val_accuracy: 0.7540
# Epoch 22/100
# 98/98 [==============================] - 22s 225ms/step - loss: 0.1857 - accuracy: 0.9406 - val_loss: 1.2143 - val_accuracy: 0.7526
# Epoch 23/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1864 - accuracy: 0.9430 - val_loss: 1.1889 - val_accuracy: 0.7500
# Epoch 24/100
# 98/98 [==============================] - 23s 238ms/step - loss: 0.1862 - accuracy: 0.9405 - val_loss: 1.2165 - val_accuracy: 0.7580
# Epoch 25/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1897 - accuracy: 0.9413 - val_loss: 1.2515 - val_accuracy: 0.7612
# Epoch 26/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1787 - accuracy: 0.9427 - val_loss: 1.2175 - val_accuracy: 0.7548
# Epoch 27/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1783 - accuracy: 0.9437 - val_loss: 1.1848 - val_accuracy: 0.7554
# Epoch 28/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1751 - accuracy: 0.9445 - val_loss: 1.2169 - val_accuracy: 0.7588
# Epoch 29/100
# 98/98 [==============================] - 22s 227ms/step - loss: 0.1905 - accuracy: 0.9394 - val_loss: 1.1939 - val_accuracy: 0.7522
# Epoch 30/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1794 - accuracy: 0.9424 - val_loss: 1.2415 - val_accuracy: 0.7570
# Epoch 31/100
# 98/98 [==============================] - 24s 243ms/step - loss: 0.1789 - accuracy: 0.9432 - val_loss: 1.1861 - val_accuracy: 0.7538
# Epoch 32/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1776 - accuracy: 0.9445 - val_loss: 1.2753 - val_accuracy: 0.7578
# Epoch 33/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1759 - accuracy: 0.9451 - val_loss: 1.2170 - val_accuracy: 0.7552
# Epoch 34/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1713 - accuracy: 0.9447 - val_loss: 1.2434 - val_accuracy: 0.7582
# Epoch 35/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1811 - accuracy: 0.9434 - val_loss: 1.1320 - val_accuracy: 0.7542
# Epoch 36/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1790 - accuracy: 0.9427 - val_loss: 1.1820 - val_accuracy: 0.7552
# Epoch 37/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1751 - accuracy: 0.9442 - val_loss: 1.2799 - val_accuracy: 0.7574
# Epoch 38/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1845 - accuracy: 0.9431 - val_loss: 1.3086 - val_accuracy: 0.7576
# Epoch 39/100
# 98/98 [==============================] - 24s 248ms/step - loss: 0.1779 - accuracy: 0.9464 - val_loss: 1.1276 - val_accuracy: 0.7574
# Epoch 40/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1807 - accuracy: 0.9434 - val_loss: 1.2751 - val_accuracy: 0.7528
# Epoch 41/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1703 - accuracy: 0.9467 - val_loss: 1.2239 - val_accuracy: 0.7592
# Epoch 42/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1795 - accuracy: 0.9425 - val_loss: 1.3402 - val_accuracy: 0.7534
# Epoch 43/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1757 - accuracy: 0.9448 - val_loss: 1.3838 - val_accuracy: 0.7542
# Epoch 44/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1764 - accuracy: 0.9448 - val_loss: 1.2645 - val_accuracy: 0.7526
# Epoch 45/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1767 - accuracy: 0.9453 - val_loss: 1.2208 - val_accuracy: 0.7500
# Epoch 46/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1735 - accuracy: 0.9457 - val_loss: 1.2428 - val_accuracy: 0.7546
# Epoch 47/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1721 - accuracy: 0.9465 - val_loss: 1.2394 - val_accuracy: 0.7532
# Epoch 48/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1710 - accuracy: 0.9462 - val_loss: 1.2877 - val_accuracy: 0.7488
# Epoch 49/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1818 - accuracy: 0.9429 - val_loss: 1.2847 - val_accuracy: 0.7526
# Epoch 50/100
# 98/98 [==============================] - 25s 256ms/step - loss: 0.1687 - accuracy: 0.9475 - val_loss: 1.3665 - val_accuracy: 0.7582
# Epoch 51/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1761 - accuracy: 0.9448 - val_loss: 1.2507 - val_accuracy: 0.7556
# Epoch 52/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1666 - accuracy: 0.9485 - val_loss: 1.2928 - val_accuracy: 0.7490
# Epoch 53/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1706 - accuracy: 0.9474 - val_loss: 1.3213 - val_accuracy: 0.7562
# Epoch 54/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1686 - accuracy: 0.9463 - val_loss: 1.1623 - val_accuracy: 0.7576
# Epoch 55/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1699 - accuracy: 0.9474 - val_loss: 1.1889 - val_accuracy: 0.7574
# Epoch 56/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1742 - accuracy: 0.9449 - val_loss: 1.3440 - val_accuracy: 0.7544
# Epoch 57/100
# 98/98 [==============================] - 22s 225ms/step - loss: 0.1691 - accuracy: 0.9470 - val_loss: 1.2606 - val_accuracy: 0.7554
# Epoch 58/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1746 - accuracy: 0.9452 - val_loss: 1.2206 - val_accuracy: 0.7590
# Epoch 59/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1658 - accuracy: 0.9482 - val_loss: 1.3424 - val_accuracy: 0.7582
# Epoch 60/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1690 - accuracy: 0.9486 - val_loss: 1.2176 - val_accuracy: 0.7518
# Epoch 61/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1705 - accuracy: 0.9477 - val_loss: 1.2849 - val_accuracy: 0.7484
# Epoch 62/100
# 98/98 [==============================] - 26s 264ms/step - loss: 0.1701 - accuracy: 0.9484 - val_loss: 1.1980 - val_accuracy: 0.7528
# Epoch 63/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1614 - accuracy: 0.9507 - val_loss: 1.3096 - val_accuracy: 0.7504
# Epoch 64/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1634 - accuracy: 0.9496 - val_loss: 1.3160 - val_accuracy: 0.7478
# Epoch 65/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1640 - accuracy: 0.9494 - val_loss: 1.3175 - val_accuracy: 0.7468
# Epoch 66/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1649 - accuracy: 0.9483 - val_loss: 1.2475 - val_accuracy: 0.7576
# Epoch 67/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1628 - accuracy: 0.9491 - val_loss: 1.2158 - val_accuracy: 0.7544
# Epoch 68/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1700 - accuracy: 0.9477 - val_loss: 1.3081 - val_accuracy: 0.7550
# Epoch 69/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1727 - accuracy: 0.9462 - val_loss: 1.2416 - val_accuracy: 0.7496
# Epoch 70/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1647 - accuracy: 0.9497 - val_loss: 1.2579 - val_accuracy: 0.7508
# Epoch 71/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1683 - accuracy: 0.9484 - val_loss: 1.1466 - val_accuracy: 0.7500
# Epoch 72/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1662 - accuracy: 0.9501 - val_loss: 1.2353 - val_accuracy: 0.7528
# Epoch 73/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1575 - accuracy: 0.9521 - val_loss: 1.2909 - val_accuracy: 0.7470
# Epoch 74/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1665 - accuracy: 0.9499 - val_loss: 1.3080 - val_accuracy: 0.7510
# Epoch 75/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1646 - accuracy: 0.9499 - val_loss: 1.3929 - val_accuracy: 0.7558
# Epoch 76/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1612 - accuracy: 0.9500 - val_loss: 1.2803 - val_accuracy: 0.7586
# Epoch 77/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1532 - accuracy: 0.9521 - val_loss: 1.4018 - val_accuracy: 0.7506
# Epoch 78/100
# 98/98 [==============================] - 27s 273ms/step - loss: 0.1598 - accuracy: 0.9516 - val_loss: 1.1996 - val_accuracy: 0.7498
# Epoch 79/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1635 - accuracy: 0.9501 - val_loss: 1.2588 - val_accuracy: 0.7544
# Epoch 80/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1652 - accuracy: 0.9485 - val_loss: 1.3438 - val_accuracy: 0.7562
# Epoch 81/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1620 - accuracy: 0.9503 - val_loss: 1.1862 - val_accuracy: 0.7578
# Epoch 82/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1666 - accuracy: 0.9512 - val_loss: 1.1985 - val_accuracy: 0.7506
# Epoch 83/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1584 - accuracy: 0.9513 - val_loss: 1.3073 - val_accuracy: 0.7512
# Epoch 84/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1629 - accuracy: 0.9498 - val_loss: 1.3377 - val_accuracy: 0.7542
# Epoch 85/100
# 98/98 [==============================] - 22s 225ms/step - loss: 0.1614 - accuracy: 0.9507 - val_loss: 1.1477 - val_accuracy: 0.7516
# Epoch 86/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1655 - accuracy: 0.9517 - val_loss: 1.3310 - val_accuracy: 0.7482
# Epoch 87/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1518 - accuracy: 0.9539 - val_loss: 1.3166 - val_accuracy: 0.7604
# Epoch 88/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1552 - accuracy: 0.9520 - val_loss: 1.3767 - val_accuracy: 0.7484
# Epoch 89/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1619 - accuracy: 0.9506 - val_loss: 1.3424 - val_accuracy: 0.7504
# Epoch 90/100
# 98/98 [==============================] - 22s 225ms/step - loss: 0.1493 - accuracy: 0.9543 - val_loss: 1.3321 - val_accuracy: 0.7480
# Epoch 91/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1525 - accuracy: 0.9527 - val_loss: 1.4564 - val_accuracy: 0.7558
# Epoch 92/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1566 - accuracy: 0.9516 - val_loss: 1.2507 - val_accuracy: 0.7514
# Epoch 93/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1627 - accuracy: 0.9516 - val_loss: 1.2404 - val_accuracy: 0.7536
# Epoch 94/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1546 - accuracy: 0.9541 - val_loss: 1.2775 - val_accuracy: 0.7492
# Epoch 95/100
# 98/98 [==============================] - 22s 223ms/step - loss: 0.1647 - accuracy: 0.9494 - val_loss: 1.2620 - val_accuracy: 0.7546
# Epoch 96/100
# 98/98 [==============================] - 22s 221ms/step - loss: 0.1535 - accuracy: 0.9526 - val_loss: 1.2197 - val_accuracy: 0.7572
# Epoch 97/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1516 - accuracy: 0.9520 - val_loss: 1.2588 - val_accuracy: 0.7546
# Epoch 98/100
# 98/98 [==============================] - 28s 287ms/step - loss: 0.1494 - accuracy: 0.9543 - val_loss: 1.2307 - val_accuracy: 0.7612
# Epoch 99/100
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1480 - accuracy: 0.9523 - val_loss: 1.2176 - val_accuracy: 0.7560
# Epoch 100/100
# 98/98 [==============================] - 22s 222ms/step - loss: 0.1463 - accuracy: 0.9552 - val_loss: 1.3287 - val_accuracy: 0.7534
# Saved trained model at /content/saved_models/cifar50_trained_model.h5
# 157/157 [==============================] - 1s 9ms/step - loss: 1.3287 - accuracy: 0.7534
# Test loss: 1.3286935091018677
# Test accuracy: 0.7534000277519226
# updating: content/ (stored 0%)
# updating: content/.config/ (stored 0%)
# updating: content/.config/.last_survey_prompt.yaml (stored 0%)
# updating: content/.config/logs/ (stored 0%)
# updating: content/.config/logs/2020.06.26/ (stored 0%)
# updating: content/.config/logs/2020.06.26/16.26.18.185568.log (deflated 54%)
# updating: content/.config/logs/2020.06.26/16.26.32.322745.log (deflated 54%)
# updating: content/.config/logs/2020.06.26/16.25.38.639070.log (deflated 92%)
# updating: content/.config/logs/2020.06.26/16.26.31.787344.log (deflated 54%)
# updating: content/.config/logs/2020.06.26/16.26.12.354762.log (deflated 87%)
# updating: content/.config/logs/2020.06.26/16.25.58.989664.log (deflated 53%)
# updating: content/.config/config_sentinel (stored 0%)
# updating: content/.config/.last_opt_in_prompt.yaml (stored 0%)
# updating: content/.config/configurations/ (stored 0%)
# updating: content/.config/configurations/config_default (deflated 15%)
# updating: content/.config/.last_update_check.json (deflated 22%)
# updating: content/.config/gce (stored 0%)
# updating: content/.config/active_config (stored 0%)
# updating: content/.config/.metricsUUID (stored 0%)
# updating: content/logs/ (stored 0%)
# updating: content/logs/train_data/ (stored 0%)
# updating: content/logs/train_data/20200703-203713/ (stored 0%)
# updating: content/logs/train_data/20200703-203713/events.out.tfevents.1593808633.0520c4c56894.122.413.v2 (deflated 2%)
# updating: content/logs/20200703-203712/ (stored 0%)
# updating: content/logs/20200703-203712/train/ (stored 0%)
# updating: content/logs/20200703-203712/train/plugins/ (stored 0%)
# updating: content/logs/20200703-203712/train/plugins/profile/ (stored 0%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/ (stored 0%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/0520c4c56894.input_pipeline.pb (deflated 58%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/0520c4c56894.tensorflow_stats.pb (deflated 70%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/0520c4c56894.trace.json.gz (deflated 1%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/0520c4c56894.overview_page.pb (deflated 61%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/0520c4c56894.kernel_stats.pb (deflated 95%)
# updating: content/logs/20200703-203712/train/events.out.tfevents.1593808633.0520c4c56894.122.709.v2 (deflated 81%)
# updating: content/logs/20200703-203712/train/events.out.tfevents.1593808642.0520c4c56894.profile-empty (deflated 5%)
# updating: content/logs/20200703-203712/validation/ (stored 0%)
# updating: content/logs/20200703-203712/validation/events.out.tfevents.1593808659.0520c4c56894.122.3706.v2 (deflated 67%)
# updating: content/logs/plots/ (stored 0%)
# updating: content/logs/plots/20200703-203703/ (stored 0%)
# updating: content/logs/plots/20200703-203703/events.out.tfevents.1593808631.0520c4c56894.122.5.v2 (deflated 1%)
# updating: content/logs/plots/20200703-203703/cm/ (stored 0%)
# updating: content/logs/plots/20200703-203703/cm/events.out.tfevents.1593808631.0520c4c56894.122.13.v2 (deflated 24%)
# updating: content/saved_models/ (stored 0%)
# updating: content/saved_models/cifar50_trained_model.h5 (deflated 9%)
# updating: content/sample_data/ (stored 0%)
# updating: content/sample_data/README.md (deflated 42%)
# updating: content/sample_data/anscombe.json (deflated 83%)
# updating: content/sample_data/mnist_test.csv (deflated 88%)
# updating: content/sample_data/california_housing_train.csv (deflated 79%)
# updating: content/sample_data/mnist_train_small.csv (deflated 88%)
# updating: content/sample_data/california_housing_test.csv (deflated 76%)
# updating: content/logs/20200703-212740/ (stored 0%)
# updating: content/logs/20200703-212740/train/ (stored 0%)
# updating: content/logs/20200703-212740/train/plugins/ (stored 0%)
# updating: content/logs/20200703-212740/train/plugins/profile/ (stored 0%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/ (stored 0%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/0520c4c56894.input_pipeline.pb (deflated 58%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/0520c4c56894.tensorflow_stats.pb (deflated 69%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/0520c4c56894.trace.json.gz (deflated 1%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/0520c4c56894.overview_page.pb (deflated 61%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/0520c4c56894.kernel_stats.pb (deflated 95%)
# updating: content/logs/20200703-212740/train/events.out.tfevents.1593811661.0520c4c56894.profile-empty (deflated 5%)
# updating: content/logs/20200703-212740/train/events.out.tfevents.1593811660.0520c4c56894.122.189767.v2 (deflated 91%)
# updating: content/logs/20200703-212740/validation/ (stored 0%)
# updating: content/logs/20200703-212740/validation/events.out.tfevents.1593811677.0520c4c56894.122.192625.v2 (deflated 67%)
# updating: content/logs/train_data/20200703-212740/ (stored 0%)
# updating: content/logs/train_data/20200703-212740/events.out.tfevents.1593811660.0520c4c56894.122.189471.v2 (deflated 2%)
# updating: content/logs/plots/20200703-212739/ (stored 0%)
# updating: content/logs/plots/20200703-212739/events.out.tfevents.1593811659.0520c4c56894.122.188860.v2 (deflated 1%)
# updating: content/logs/plots/20200703-212739/cm/ (stored 0%)
# updating: content/logs/plots/20200703-212739/cm/events.out.tfevents.1593811659.0520c4c56894.122.188868.v2 (deflated 27%)
# updating: content/logs/20200703-220827/ (stored 0%)
# updating: content/logs/20200703-220827/train/ (stored 0%)
# updating: content/logs/20200703-220827/train/plugins/ (stored 0%)
# updating: content/logs/20200703-220827/train/plugins/profile/ (stored 0%)
# updating: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/ (stored 0%)
# updating: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/0520c4c56894.input_pipeline.pb (deflated 58%)
# updating: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/0520c4c56894.tensorflow_stats.pb (deflated 70%)
# updating: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/0520c4c56894.trace.json.gz (deflated 1%)
# updating: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/0520c4c56894.overview_page.pb (deflated 60%)
# updating: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/0520c4c56894.kernel_stats.pb (deflated 95%)
# updating: content/logs/20200703-220827/train/events.out.tfevents.1593814114.0520c4c56894.profile-empty (deflated 5%)
# updating: content/logs/20200703-220827/train/events.out.tfevents.1593814107.0520c4c56894.122.378686.v2 (deflated 92%)
# updating: content/logs/20200703-220827/validation/ (stored 0%)
# updating: content/logs/20200703-220827/validation/events.out.tfevents.1593814133.0520c4c56894.122.380662.v2 (deflated 46%)
# updating: content/logs/train_data/20200703-220827/ (stored 0%)
# updating: content/logs/train_data/20200703-220827/events.out.tfevents.1593814107.0520c4c56894.122.378390.v2 (deflated 2%)
# updating: content/logs/plots/20200703-220825/ (stored 0%)
# updating: content/logs/plots/20200703-220825/events.out.tfevents.1593814105.0520c4c56894.122.377779.v2 (deflated 1%)
# updating: content/logs/plots/20200703-220825/cm/ (stored 0%)
# updating: content/logs/plots/20200703-220825/cm/events.out.tfevents.1593814105.0520c4c56894.122.377787.v2 (deflated 28%)
# updating: content/logs/train_data/20200703-221128/ (stored 0%)
# updating: content/logs/train_data/20200703-221128/events.out.tfevents.1593814288.0520c4c56894.122.384519.v2 (deflated 2%)
# updating: content/logs/20200703-221128/ (stored 0%)
# updating: content/logs/20200703-221128/train/ (stored 0%)
# updating: content/logs/20200703-221128/train/plugins/ (stored 0%)
# updating: content/logs/20200703-221128/train/plugins/profile/ (stored 0%)
# updating: content/logs/20200703-221128/train/plugins/profile/2020_07_03_22_11_30/ (stored 0%)
# updating: content/logs/20200703-221128/train/plugins/profile/2020_07_03_22_11_30/0520c4c56894.input_pipeline.pb (deflated 57%)
# updating: content/logs/20200703-221128/train/plugins/profile/2020_07_03_22_11_30/0520c4c56894.tensorflow_stats.pb (deflated 70%)
# updating: content/logs/20200703-221128/train/plugins/profile/2020_07_03_22_11_30/0520c4c56894.trace.json.gz (deflated 1%)
# updating: content/logs/20200703-221128/train/plugins/profile/2020_07_03_22_11_30/0520c4c56894.overview_page.pb (deflated 60%)
# updating: content/logs/20200703-221128/train/plugins/profile/2020_07_03_22_11_30/0520c4c56894.kernel_stats.pb (deflated 95%)
# updating: content/logs/20200703-221128/train/events.out.tfevents.1593814289.0520c4c56894.122.384815.v2 (deflated 91%)
# updating: content/logs/20200703-221128/train/events.out.tfevents.1593814290.0520c4c56894.profile-empty (deflated 5%)
# updating: content/logs/20200703-221128/validation/ (stored 0%)
# updating: content/logs/20200703-221128/validation/events.out.tfevents.1593814304.0520c4c56894.122.386791.v2 (deflated 68%)
# updating: content/logs/plots/20200703-221126/ (stored 0%)
# updating: content/logs/plots/20200703-221126/events.out.tfevents.1593814286.0520c4c56894.122.383908.v2 (deflated 1%)
# updating: content/logs/plots/20200703-221126/cm/ (stored 0%)
# updating: content/logs/plots/20200703-221126/cm/events.out.tfevents.1593814286.0520c4c56894.122.383916.v2 (deflated 28%)
#   adding: content/logs/20200703-231602/ (stored 0%)
#   adding: content/logs/20200703-231602/train/ (stored 0%)
#   adding: content/logs/20200703-231602/train/plugins/ (stored 0%)
#   adding: content/logs/20200703-231602/train/plugins/profile/ (stored 0%)
#   adding: content/logs/20200703-231602/train/plugins/profile/2020_07_03_23_16_07/ (stored 0%)
#   adding: content/logs/20200703-231602/train/plugins/profile/2020_07_03_23_16_07/0520c4c56894.input_pipeline.pb (deflated 58%)
#   adding: content/logs/20200703-231602/train/plugins/profile/2020_07_03_23_16_07/0520c4c56894.tensorflow_stats.pb (deflated 71%)
#   adding: content/logs/20200703-231602/train/plugins/profile/2020_07_03_23_16_07/0520c4c56894.trace.json.gz (deflated 1%)
#   adding: content/logs/20200703-231602/train/plugins/profile/2020_07_03_23_16_07/0520c4c56894.overview_page.pb (deflated 61%)
#   adding: content/logs/20200703-231602/train/plugins/profile/2020_07_03_23_16_07/0520c4c56894.kernel_stats.pb (deflated 95%)
#   adding: content/logs/20200703-231602/train/events.out.tfevents.1593818167.0520c4c56894.profile-empty (deflated 5%)
#   adding: content/logs/20200703-231602/train/events.out.tfevents.1593818163.0520c4c56894.122.485534.v2 (deflated 91%)
#   adding: content/logs/20200703-231602/validation/ (stored 0%)
#   adding: content/logs/20200703-231602/validation/events.out.tfevents.1593818184.0520c4c56894.122.487804.v2 (deflated 67%)
#   adding: content/logs/train_data/20200703-231602/ (stored 0%)
#   adding: content/logs/train_data/20200703-231602/events.out.tfevents.1593818162.0520c4c56894.122.485238.v2 (deflated 2%)
#   adding: content/logs/plots/20200703-231600/ (stored 0%)
#   adding: content/logs/plots/20200703-231600/events.out.tfevents.1593818160.0520c4c56894.122.484627.v2 (deflated 1%)
#   adding: content/logs/plots/20200703-231600/cm/ (stored 0%)
#   adding: content/logs/plots/20200703-231600/cm/events.out.tfevents.1593818160.0520c4c56894.122.484635.v2 (deflated 28%)

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# %%
# !rm -rf logs

# %%
[1]*10**10

# %%
# !zip -r /content/file.zip /content
from google.colab import files
files.download("/content/file.zip")
# Out:
# updating: content/ (stored 0%)
# updating: content/.config/ (stored 0%)
# updating: content/.config/.last_survey_prompt.yaml (stored 0%)
# updating: content/.config/logs/ (stored 0%)
# updating: content/.config/logs/2020.06.26/ (stored 0%)
# updating: content/.config/logs/2020.06.26/16.26.18.185568.log (deflated 54%)
# updating: content/.config/logs/2020.06.26/16.26.32.322745.log (deflated 54%)
# updating: content/.config/logs/2020.06.26/16.25.38.639070.log (deflated 92%)
# updating: content/.config/logs/2020.06.26/16.26.31.787344.log (deflated 54%)
# updating: content/.config/logs/2020.06.26/16.26.12.354762.log (deflated 87%)
# updating: content/.config/logs/2020.06.26/16.25.58.989664.log (deflated 53%)
# updating: content/.config/config_sentinel (stored 0%)
# updating: content/.config/.last_opt_in_prompt.yaml (stored 0%)
# updating: content/.config/configurations/ (stored 0%)
# updating: content/.config/configurations/config_default (deflated 15%)
# updating: content/.config/.last_update_check.json (deflated 22%)
# updating: content/.config/gce (stored 0%)
# updating: content/.config/active_config (stored 0%)
# updating: content/.config/.metricsUUID (stored 0%)
# updating: content/logs/ (stored 0%)
# updating: content/logs/train_data/ (stored 0%)
# updating: content/logs/train_data/20200703-203713/ (stored 0%)
# updating: content/logs/train_data/20200703-203713/events.out.tfevents.1593808633.0520c4c56894.122.413.v2 (deflated 2%)
# updating: content/logs/20200703-203712/ (stored 0%)
# updating: content/logs/20200703-203712/train/ (stored 0%)
# updating: content/logs/20200703-203712/train/plugins/ (stored 0%)
# updating: content/logs/20200703-203712/train/plugins/profile/ (stored 0%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/ (stored 0%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/0520c4c56894.input_pipeline.pb (deflated 58%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/0520c4c56894.tensorflow_stats.pb (deflated 70%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/0520c4c56894.trace.json.gz (deflated 1%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/0520c4c56894.overview_page.pb (deflated 61%)
# updating: content/logs/20200703-203712/train/plugins/profile/2020_07_03_20_37_22/0520c4c56894.kernel_stats.pb (deflated 95%)
# updating: content/logs/20200703-203712/train/events.out.tfevents.1593808633.0520c4c56894.122.709.v2 (deflated 81%)
# updating: content/logs/20200703-203712/train/events.out.tfevents.1593808642.0520c4c56894.profile-empty (deflated 5%)
# updating: content/logs/20200703-203712/validation/ (stored 0%)
# updating: content/logs/20200703-203712/validation/events.out.tfevents.1593808659.0520c4c56894.122.3706.v2 (deflated 67%)
# updating: content/logs/plots/ (stored 0%)
# updating: content/logs/plots/20200703-203703/ (stored 0%)
# updating: content/logs/plots/20200703-203703/events.out.tfevents.1593808631.0520c4c56894.122.5.v2 (deflated 1%)
# updating: content/logs/plots/20200703-203703/cm/ (stored 0%)
# updating: content/logs/plots/20200703-203703/cm/events.out.tfevents.1593808631.0520c4c56894.122.13.v2 (deflated 24%)
# updating: content/saved_models/ (stored 0%)
# updating: content/saved_models/cifar50_trained_model.h5 (deflated 9%)
# updating: content/sample_data/ (stored 0%)
# updating: content/sample_data/README.md (deflated 42%)
# updating: content/sample_data/anscombe.json (deflated 83%)
# updating: content/sample_data/mnist_test.csv (deflated 88%)
# updating: content/sample_data/california_housing_train.csv (deflated 79%)
# updating: content/sample_data/mnist_train_small.csv (deflated 88%)
# updating: content/sample_data/california_housing_test.csv (deflated 76%)
# updating: content/logs/20200703-212740/ (stored 0%)
# updating: content/logs/20200703-212740/train/ (stored 0%)
# updating: content/logs/20200703-212740/train/plugins/ (stored 0%)
# updating: content/logs/20200703-212740/train/plugins/profile/ (stored 0%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/ (stored 0%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/0520c4c56894.input_pipeline.pb (deflated 58%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/0520c4c56894.tensorflow_stats.pb (deflated 69%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/0520c4c56894.trace.json.gz (deflated 1%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/0520c4c56894.overview_page.pb (deflated 61%)
# updating: content/logs/20200703-212740/train/plugins/profile/2020_07_03_21_27_41/0520c4c56894.kernel_stats.pb (deflated 95%)
# updating: content/logs/20200703-212740/train/events.out.tfevents.1593811661.0520c4c56894.profile-empty (deflated 5%)
# updating: content/logs/20200703-212740/train/events.out.tfevents.1593811660.0520c4c56894.122.189767.v2 (deflated 91%)
# updating: content/logs/20200703-212740/validation/ (stored 0%)
# updating: content/logs/20200703-212740/validation/events.out.tfevents.1593811677.0520c4c56894.122.192625.v2 (deflated 67%)
# updating: content/logs/train_data/20200703-212740/ (stored 0%)
# updating: content/logs/train_data/20200703-212740/events.out.tfevents.1593811660.0520c4c56894.122.189471.v2 (deflated 2%)
# updating: content/logs/plots/20200703-212739/ (stored 0%)
# updating: content/logs/plots/20200703-212739/events.out.tfevents.1593811659.0520c4c56894.122.188860.v2 (deflated 1%)
# updating: content/logs/plots/20200703-212739/cm/ (stored 0%)
# updating: content/logs/plots/20200703-212739/cm/events.out.tfevents.1593811659.0520c4c56894.122.188868.v2 (deflated 27%)
#   adding: content/logs/20200703-220827/ (stored 0%)
#   adding: content/logs/20200703-220827/train/ (stored 0%)
#   adding: content/logs/20200703-220827/train/plugins/ (stored 0%)
#   adding: content/logs/20200703-220827/train/plugins/profile/ (stored 0%)
#   adding: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/ (stored 0%)
#   adding: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/0520c4c56894.input_pipeline.pb (deflated 58%)
#   adding: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/0520c4c56894.tensorflow_stats.pb (deflated 70%)
#   adding: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/0520c4c56894.trace.json.gz (deflated 1%)
#   adding: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/0520c4c56894.overview_page.pb (deflated 60%)
#   adding: content/logs/20200703-220827/train/plugins/profile/2020_07_03_22_08_34/0520c4c56894.kernel_stats.pb (deflated 95%)
#   adding: content/logs/20200703-220827/train/events.out.tfevents.1593814114.0520c4c56894.profile-empty (deflated 5%)
#   adding: content/logs/20200703-220827/train/events.out.tfevents.1593814107.0520c4c56894.122.378686.v2 (deflated 92%)
#   adding: content/logs/20200703-220827/validation/ (stored 0%)
#   adding: content/logs/20200703-220827/validation/events.out.tfevents.1593814133.0520c4c56894.122.380662.v2 (deflated 46%)
#   adding: content/logs/train_data/20200703-220827/ (stored 0%)
#   adding: content/logs/train_data/20200703-220827/events.out.tfevents.1593814107.0520c4c56894.122.378390.v2 (deflated 2%)
#   adding: content/logs/plots/20200703-220825/ (stored 0%)
#   adding: content/logs/plots/20200703-220825/events.out.tfevents.1593814105.0520c4c56894.122.377779.v2 (deflated 1%)
#   adding: content/logs/plots/20200703-220825/cm/ (stored 0%)
#   adding: content/logs/plots/20200703-220825/cm/events.out.tfevents.1593814105.0520c4c56894.122.377787.v2 (deflated 28%)
